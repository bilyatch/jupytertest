# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Samir**<p>
# I want to be a data scientist.

# %% [markdown]
# *I'm intrested in data science because I found it really intresting like working on raw data to find out the real beauty of data. We are able to detect many holes in the data which can be structured and can get highly refined data which will be more accurate and reliable.*

# %% [markdown]
# ### Multiplication

# %%
a=5
b=7
a*b
# Out:
# 35

# %% [markdown]
# **Name**
# ***
# * Harry
# * Zenith
# * Simon
# ***
# *Below you can see how to insert image in `jupyter notebook`*
# ![alt text](https://images-na.ssl-images-amazon.com/images/I/81rEhhwbubL.jpg "one piece")
# ***
# [Hyperlink to google homepage](https://www.google.com")
#
# > That's all we have done in this ~~code cell~~ markdown cell.
#
# > Thank you :)
